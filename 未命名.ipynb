# %%
import sys
import numpy as np
from metabci.brainda.datasets import Wang2016
from metabci.brainda.paradigms import SSVEP
from metabci.brainda.algorithms.utils.model_selection import (
    set_random_seeds,
    generate_kfold_indices, match_kfold_indices)
from metabci.brainda.algorithms.decomposition import FBECCA
from metabci.brainda.algorithms.decomposition.base import generate_filterbank, generate_cca_references

# %%
wp=[(5,90),(14,90),(22,90),(30,90),(38,90)]
ws=[(3,92),(12,92),(20,92),(28,92),(36,92)]

# %%
filterbank = generate_filterbank(wp,ws,srate=250,order=15,rp=0.5)

dataset = Wang2016()

events = dataset.events.keys()
freq_list = [dataset.get_freq(event) for event in events]

Yf = generate_cca_references(freq_list, srate=250, T=0.5,n_harmonics = 5)

paradigm = SSVEP(
    channels=['POZ', 'PZ', 'PO3', 'PO5', 'PO4', 'PO6', 'O1', 'OZ', 'O2'],
    intervals=[(0.14, 0.64)],
    srate=250
)

# %%
def raw_hook(raw, caches):
    # do something with raw object
    raw.filter(5, 90, l_trans_bandwidth=2,h_trans_bandwidth=5,
        phase='zero-double')
    caches['raw_stage'] = caches.get('raw_stage', -1) + 1
    return raw, caches

def epochs_hook(epochs, caches):
    # do something with epochs object
    # print(epochs.event_id)
    caches['epoch_stage'] = caches.get('epoch_stage', -1) + 1
    return epochs, caches

def data_hook(X, y, meta, caches):
    # retrive caches from the last stage
    # print("Raw stage:{},Epochs stage:{}".format(caches['raw_stage'], caches['epoch_stage']))
    # do something with X, y, and meta
    caches['data_stage'] = caches.get('data_stage', -1) + 1
    return X, y, meta, caches
paradigm.register_raw_hook(raw_hook)
paradigm.register_epochs_hook(epochs_hook)
paradigm.register_data_hook(data_hook)

# %%
X, y, meta = paradigm.get_data(
    dataset,
    subjects=[1],
    return_concat=True,
    n_jobs=None,
    verbose=False)

# 6-fold cross validation
set_random_seeds(38)
kfold = 6
indices = generate_kfold_indices(meta, kfold=kfold)
# Out:
# --------ssssss, /upload/yijun/S1.mat.7z
# ---------------------------------------------------------------------------
# Bad7zFile                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 X, y, meta = paradigm.get_data(
#       2     dataset,
#       3     subjects=[1],
#       4     return_concat=True,
#       5     n_jobs=None,
#       6     verbose=False)
#       8 # 6-fold cross validation
#       9 set_random_seeds(38)
#
# File <decorator-gen-455>:10, in get_data(self, dataset, subjects, label_encode, return_concat, n_jobs, verbose)
#
# File D:\WORK_space\Code_WS\code_localized\MetaBCI\metabci\brainda\paradigms\base.py:377, in BaseParadigm.get_data(self, dataset, subjects, label_encode, return_concat, n_jobs, verbose)
#     373 ys = {}
#     374 metas = {}
#     376 X, y, meta = zip(
# --> 377     *Parallel(n_jobs=n_jobs)(
#     378         delayed(self._get_single_subject_data)(
#     379             dataset, sub_id, verbose=verbose)
#     380         for sub_id in subjects
#     381     )
#     382 )
#     384 for event_name in used_events.keys():
#     385     Xs[event_name] = np.concatenate(
#     386         [X[i][event_name]
#     387          for i in range(len(subjects)) if event_name in X[i]],
#     388         axis=0,
#     389     )
#
# File D:\Anaconda\envs\BCI\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File D:\Anaconda\envs\BCI\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File <decorator-gen-454>:10, in _get_single_subject_data(self, dataset, subject_id, verbose)
#
# File D:\WORK_space\Code_WS\code_localized\MetaBCI\metabci\brainda\paradigms\base.py:195, in BaseParadigm._get_single_subject_data(self, dataset, subject_id, verbose)
#     192 ys = {}
#     193 metas = {}
# --> 195 data = dataset.get_data([subject_id])
#     197 for subject, sessions in data.items():
#     198     for session, runs in sessions.items():
#
# File <decorator-gen-201>:12, in get_data(self, subjects, verbose)
#
# File D:\WORK_space\Code_WS\code_localized\MetaBCI\metabci\brainda\datasets\base.py:169, in BaseDataset.get_data(self, subjects, verbose)
#     167     if subject not in self.subjects:
#     168         raise ValueError("Invalid subject {} given".format(subject))
# --> 169     data[subject] = self._get_single_subject_data(subject)
#     170 return data
#
# File D:\WORK_space\Code_WS\code_localized\MetaBCI\metabci\brainda\datasets\tsinghua.py:167, in Wang2016._get_single_subject_data(self, subject, verbose)
#     164 def _get_single_subject_data(
#     165     self, subject: Union[str, int], verbose: Optional[Union[bool, str, int]] = None
#     166 ) -> Dict[str, Dict[str, Raw]]:
# --> 167     dests = self.data_path(subject)
#     168     raw_mat = loadmat(dests[0][0])
#     169     epoch_data = raw_mat["data"] * 1e-6
#
# File D:\WORK_space\Code_WS\code_localized\MetaBCI\metabci\brainda\datasets\tsinghua.py:159, in Wang2016.data_path(self, subject, path, force_update, update_path, proxies, verbose)
#     156 subject_file = file_dest[:-3]
#     157 if not os.path.exists(subject_file):
#     158     # decompression the data
# --> 159     with py7zr.SevenZipFile(file_dest, "r") as archive:
#     160         archive.extractall(path=Path(file_dest).parent)
#     161 dests = [[subject_file]]
#
# File D:\Anaconda\envs\BCI\lib\site-packages\py7zr\py7zr.py:416, in SevenZipFile.__init__(self, file, mode, filters, dereference, password, header_encryption, blocksize, mp)
#     414 except Exception as e:
#     415     self._fpclose()
# --> 416     raise e
#     417 self._dict: Dict[str, IO[Any]] = {}
#     418 self.dereference = dereference
#
# File D:\Anaconda\envs\BCI\lib\site-packages\py7zr\py7zr.py:397, in SevenZipFile.__init__(self, file, mode, filters, dereference, password, header_encryption, blocksize, mp)
#     395 try:
#     396     if mode == "r":
# --> 397         self._real_get_contents(password)
#     398         self.fp.seek(self.afterheader)  # seek into start of payload and prepare worker to extract
#     399         self.worker = Worker(self.files, self.afterheader, self.header, self.mp)
#
# File D:\Anaconda\envs\BCI\lib\site-packages\py7zr\py7zr.py:436, in SevenZipFile._real_get_contents(self, password)
#     434 def _real_get_contents(self, password) -> None:
#     435     if not self._check_7zfile(self.fp):
# --> 436         raise Bad7zFile("not a 7z file")
#     437     self.sig_header = SignatureHeader.retrieve(self.fp)
#     438     self.afterheader: int = self.fp.tell()
#
# Bad7zFile: not a 7z file
